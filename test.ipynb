# %%
print("hello world")
# Out:
# hello world

# %%
a=5

# %%
print(a)
# Out:
# 5

# %%
def add(x,y):
    return x+y

# %%
add(2,3)
# Out:
# 5

# %%
a = [500,62,6,7,8,9]
a
# Out:
# [500, 62, 6, 7, 8, 9]

# %%
def sum_list(v):
    sum = 0
    for i in v:
        sum = sum + i
     
    
    return sum

# %%
x = sum_list(a)
x
# Out:
# 97

# %%
def smallest(v):
    small = v[0]
    pos = 0
    for i in range(len(v)):
        if v[i] < small:
            small = v[i]
            pos = i
    print(pos)
    return small

# %%
smallest(a)
# Out:
# 2
# 6

# %%
min(a)
# Out:
# 6

# %%
sum(a)
# Out:
# 592
